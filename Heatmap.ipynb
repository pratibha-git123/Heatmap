# %%
import seaborn as sns
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df =pd.read_csv('data.csv')
df
# Out:
#    duration  marks
# 0         5     77
# 1         5     76
# 2         4     55
# 3         3     44
# 4         2     33

# %%
df.corr()
# Out:
#           duration     marks
# duration  1.000000  0.986863
# marks     0.986863  1.000000

# %%
sns.heatmap(df.corr())
# Out:
# <Axes: >

# %%
sns.heatmap(df.corr(),annot=True,cmap='cool')
# Out:
# <Axes: >

# %%
sns.heatmap(df.corr(),annot=True,cmap='cool',linewidth=7)
# Out:
# <Axes: >

# %%
plt.figure(figsize=(4,4))
sns.heatmap(df.corr(),annot=True,cmap='cool',linewidth=7)
# Out:
# <Axes: >

# %%
plt.figure(figsize=(4,4))
sns.heatmap(df.corr(),annot=True,cmap='cool',linewidth=7,linecolor='k')
# Out:
# <Axes: >

# %%
plt.figure(figsize=(4,4))
sns.heatmap(df.corr(),annot=True,cmap='cool',linewidth=7,linecolor='k',cbar=False)
# Out:
# <Axes: >
